# %% [markdown]
# # CUREYA
# ### TASK - 4

# %%
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import sklearn

# %%
# Loading Data
Df = pd.read_csv("data.csv")
Df.head()
# Out:
#                Date      Price  Bedrooms  ...       City  Statezip  Country
# 0  02-05-2014 00:00   313000.0         3  ...  Shoreline  WA 98133      USA
# 1  02-05-2014 00:00  2384000.0         5  ...    Seattle  WA 98119      USA
# 2  02-05-2014 00:00   342000.0         3  ...       Kent  WA 98042      USA
# 3  02-05-2014 00:00   420000.0         3  ...   Bellevue  WA 98008      USA
# 4  02-05-2014 00:00   550000.0         4  ...    Redmond  WA 98052      USA
#
# [5 rows x 18 columns]

# %%
# Checking the Columns 
Df.columns
# Out:
# Index(['Date', 'Price', 'Bedrooms', 'Bathrooms', 'Sqft_living', 'Sqft_lot',
#        'Floors', 'Waterfront', 'View', 'Condition', 'Sqft_above',
#        'Sqft_basement', 'Yr_built', 'Yr_renovated', 'Street', 'City',
#        'Statezip', 'Country'],
#       dtype='object')

# %%
# Shape of Data
Df.shape
# Out:
# (4600, 18)

# %%
# Size of Data
Df.size
# Out:
# 82800

# %%
# Data Type
Df.dtypes
# Out:
# Date              object
# Price            float64
# Bedrooms           int64
# Bathrooms        float64
# Sqft_living        int64
# Sqft_lot           int64
# Floors           float64
# Waterfront         int64
# View               int64
# Condition          int64
# Sqft_above         int64
# Sqft_basement      int64
# Yr_built           int64
# Yr_renovated       int64
# Street            object
# City              object
# Statezip          object
# Country           object
# dtype: object

# %%
# Data Info 
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           4600 non-null   object
#  1   Price          4600 non-null   float64
#  2   Bedrooms       4600 non-null   int64
#  3   Bathrooms      4600 non-null   float64
#  4   Sqft_living    4600 non-null   int64
#  5   Sqft_lot       4600 non-null   int64
#  6   Floors         4600 non-null   float64
#  7   Waterfront     4600 non-null   int64
#  8   View           4600 non-null   int64
#  9   Condition      4600 non-null   int64
#  10  Sqft_above     4600 non-null   int64
#  11  Sqft_basement  4600 non-null   int64
#  12  Yr_built       4600 non-null   int64
#  13  Yr_renovated   4600 non-null   int64
#  14  Street         4600 non-null   object
#  15  City           4600 non-null   object
#  16  Statezip       4600 non-null   object
#  17  Country        4600 non-null   object
# dtypes: float64(3), int64(10), object(5)
# memory usage: 647.0+ KB

# %%
# Is there any na value or not
Df.isna().sum()
# Out:
# Date             0
# Price            0
# Bedrooms         0
# Bathrooms        0
# Sqft_living      0
# Sqft_lot         0
# Floors           0
# Waterfront       0
# View             0
# Condition        0
# Sqft_above       0
# Sqft_basement    0
# Yr_built         0
# Yr_renovated     0
# Street           0
# City             0
# Statezip         0
# Country          0
# dtype: int64

# %%
# With the help of heatmap we will check is there any N.A value or not  
plt.figure(figsize=(24,12))
sns.heatmap(Df.isnull(),annot=True,cbar=False,cmap="Dark2")
plt.show()

# %%
# Checking is there any Duplicate in the Dataset or not
Df.duplicated().sum()
# Out:
# 0

# %%
# Dropping unnecessary Columns
Df = Df.drop(columns="Date",axis=1)
Df = Df.drop(columns="Country",axis=1)
Df = Df.drop(columns="Statezip",axis=1)
Df = Df.drop(columns="Street",axis=1)

# %%
# Cheching Head
Df.head()
# Out:
#        Price  Bedrooms  Bathrooms  ...  Yr_built  Yr_renovated       City
# 0   313000.0         3       1.50  ...      1955          2005  Shoreline
# 1  2384000.0         5       2.50  ...      1921             0    Seattle
# 2   342000.0         3       2.00  ...      1966             0       Kent
# 3   420000.0         3       2.25  ...      1963             0   Bellevue
# 4   550000.0         4       2.50  ...      1976          1992    Redmond
#
# [5 rows x 14 columns]

# %%
# describe of Data 
Df.describe().T
# Out:
#                 count           mean  ...        75%         max
# Price          4600.0  551962.988473  ...  654962.50  26590000.0
# Bedrooms       4600.0       3.400870  ...       4.00         9.0
# Bathrooms      4600.0       2.160815  ...       2.50         8.0
# Sqft_living    4600.0    2139.346957  ...    2620.00     13540.0
# Sqft_lot       4600.0   14852.516087  ...   11001.25   1074218.0
# Floors         4600.0       1.512065  ...       2.00         3.5
# Waterfront     4600.0       0.007174  ...       0.00         1.0
# View           4600.0       0.240652  ...       0.00         4.0
# Condition      4600.0       3.451739  ...       4.00         5.0
# Sqft_above     4600.0    1827.265435  ...    2300.00      9410.0
# Sqft_basement  4600.0     312.081522  ...     610.00      4820.0
# Yr_built       4600.0    1970.786304  ...    1997.00      2014.0
# Yr_renovated   4600.0     808.608261  ...    1999.00      2014.0
#
# [13 rows x 8 columns]

# %%
Min_Threshhold,Max_Threshold=Df["Price"].quantile([0.01,0.99])
Min_Threshhold,Max_Threshold
# Out:
# (0.0, 2005220.0000000047)

# %%
Df[Df["Price"]<Min_Threshhold]
# Out:
# Empty DataFrame
# Columns: [Price, Bedrooms, Bathrooms, Sqft_living, Sqft_lot, Floors, Waterfront, View, Condition, Sqft_above, Sqft_basement, Yr_built, Yr_renovated, City]
# Index: []

# %%
Df[Df["Price"]>Max_Threshold]
# Out:
#              Price  Bedrooms  Bathrooms  ...  Yr_built  Yr_renovated           City
# 1     2.384000e+06         5       2.50  ...      1921             0        Seattle
# 122   2.280000e+06         7       8.00  ...      1999             0        Redmond
# 252   3.200000e+06         7       4.50  ...      1910             0        Seattle
# 404   2.400000e+06         3       2.25  ...      2001             0      Sammamish
# 462   2.238888e+06         5       6.50  ...      2010             0       Issaquah
# 581   2.555000e+06         4       2.50  ...      1923             0        Seattle
# 745   2.100000e+06         4       1.75  ...      1962          2002         Medina
# 1132  2.700000e+06         5       4.75  ...      2005             0       Kirkland
# 1209  2.150000e+06         4       5.50  ...      2008             0       Bellevue
# 1543  2.453500e+06         4       3.50  ...      1935             0        Seattle
# 1567  3.100000e+06         6       4.25  ...      1999             0  Mercer Island
# 1571  2.750000e+06         4       3.25  ...      1952          2007         Medina
# 1600  2.400000e+06         4       3.25  ...      1977          2005     Clyde Hill
# 1637  3.710000e+06         4       3.50  ...      2000             0         Medina
# 1858  2.400000e+06         5       3.25  ...      1912          1994        Seattle
# 2083  2.700000e+06         4       3.25  ...      2001             0       Bellevue
# 2286  7.062500e+06         5       4.50  ...      1940          2001       Bellevue
# 2328  2.888000e+06         5       6.25  ...      1965          2003        Seattle
# 2364  2.250000e+06         5       4.25  ...      1905             0        Seattle
# 2654  4.668000e+06         5       6.75  ...      1983          2009  Mercer Island
# 2711  2.027000e+06         4       3.75  ...      1934          1979  Mercer Island
# 2712  2.475000e+06         3       3.25  ...      1993             0        Seattle
# 2761  4.489000e+06         4       3.00  ...      2001             0       Bellevue
# 2772  3.000000e+06         4       4.25  ...      1989             0       Kirkland
# 2846  2.200000e+06         5       4.75  ...      2002             0       Issaquah
# 2978  2.110000e+06         3       2.25  ...      1973             0       Bellevue
# 2980  2.400000e+06         6       4.50  ...      1999             0        Seattle
# 3058  2.075000e+06         4       3.50  ...      1997             0       Bellevue
# 3202  2.466350e+06         5       4.75  ...      1940          1996        Seattle
# 3284  2.300000e+06         4       3.25  ...      2004          2003       Bellevue
# 3699  2.065000e+06         4       3.75  ...      2013          1923       Bellevue
# 3729  3.800000e+06         5       5.50  ...      1978          2000     Clyde Hill
# 3781  2.300000e+06         4       4.75  ...      1928             0        Seattle
# 3791  2.367000e+06         3       2.25  ...      1930          1993  Mercer Island
# 3863  2.271150e+06         4       3.25  ...      1954          1979         Medina
# 3873  2.147500e+06         3       3.50  ...      1909          1988        Seattle
# 3959  2.351956e+06         4       4.25  ...      2014             0  Mercer Island
# 4135  2.458000e+06         4       5.25  ...      2001             0         Medina
# 4143  2.180000e+06         6       2.75  ...      1931             0        Seattle
# 4261  2.680000e+06         5       3.00  ...      1985             0         Medina
# 4273  2.321000e+06         5       4.75  ...      2006             0  Mercer Island
# 4346  1.289900e+07         3       2.50  ...      1956          2001        Seattle
# 4347  2.110000e+06         4       1.00  ...      1959          1989        Tukwila
# 4348  2.199900e+06         4       1.50  ...      1969          2014      Covington
# 4350  2.659000e+07         3       2.00  ...      1992             0           Kent
# 4465  2.560498e+06         3       2.50  ...      2003             0        Seattle
#
# [46 rows x 14 columns]

# %%
Df = Df[(Df["Price"]< Max_Threshold) & (Df["Price"]>Min_Threshhold)]

# %%
Df.shape
# Out:
# (4505, 14)

# %%
# Correlation with the help of Heatmap
plt.figure(figsize=(16,8))
sns.heatmap(Df.corr(),cmap="flare_r",annot=True,cbar=False)
plt.show()

# %%
# Pairplot of Data
plt.figure(figsize=(8,5))
sns.pairplot(Df,kind="kde")
plt.show()

# %% [markdown]
# ## Exploratory Data Analysis

# %%
Df.hist(bins=20,figsize=(20,15))
plt.show()

# %%
# Price
plt.figure(figsize=(10,5))
sns.boxplot(x="Price",data=Df)
plt.show()

# %%
# Chechking No od City in the Data 
Df.City.value_counts()
# Out:
# Seattle                1546
# Renton                  291
# Bellevue                273
# Redmond                 234
# Kirkland                185
# Issaquah                184
# Kent                    183
# Auburn                  175
# Sammamish               170
# Federal Way             145
# Shoreline               123
# Woodinville             114
# Maple Valley             95
# Mercer Island            76
# Burien                   72
# Snoqualmie               69
# Kenmore                  65
# Des Moines               58
# North Bend               50
# Duvall                   42
# Covington                41
# Lake Forest Park         34
# Newcastle                33
# Bothell                  33
# Vashon                   29
# SeaTac                   28
# Tukwila                  28
# Enumclaw                 27
# Carnation                22
# Normandy Park            17
# Fall City                11
# Black Diamond             8
# Clyde Hill                7
# Ravensdale                7
# Pacific                   6
# Algona                    5
# Medina                    5
# Yarrow Point              4
# Skykomish                 3
# Preston                   2
# Milton                    2
# Inglewood-Finn Hill       1
# Snoqualmie Pass           1
# Beaux Arts Village        1
# Name: City, dtype: int64

# %%
# Plotting City by Price
plt.figure(figsize=(28,12))
sns.barplot(x="Price",y="City",data=Df,color="Red")

# %%
# City by Price
px.bar(Df, y='Price', x='City', title="City by Price",color="City")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="54b691e1-6808-43df-8214-0ae479514265" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("54b691e1-6808-43df-8214-0ae479514265")) {
#                     Plotly.newPlot(
#                         '54b691e1-6808-43df-8214-0ae479514265',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "City=%{x}<br>Price=%{y}", "legendgroup": "City=Shoreline", "marker": {"color": "#636efa"}, "name": "City=Shoreline", "offsetgroup": "City=Shoreline", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline", "Shoreline"], "xaxis": "x", "y": [313000.0, 625000.0, 308500.0, 400000.0, 379950.0, 250000.0, 367500.0, 655500.0, 510000.0, 492000.0, 405000.0, 341000.0, 339000.0, 449500.0, 464000.0, 370000.0, 543000.0, 364000.0, 930000.0, 310000.0, 267800.0, 300000.0, 375000.0, 400000.0, 240000.0, 282613.0, 379950.0, 366500.0, 475000.0, 1000000.0, 268500.0, 299950.0, 372500.0, 668750.0, 970000.0, 430000.0, 377691.0, 350000.0, 355300.0, 370000.0, 360000.0, 405000.0, 415000.0, 255000.0, 313000.0, 254000.0, 299000.0, 305000.0, 941500.0, 500000.0, 324950.0, 275000.0, 415000.0, 2005000.0, 395000.0, 680000.0, 360000.0, 805000.0, 345000.0, 380000.0, 310000.0, 307000.0, 359950.0, 371500.0, 515000.0, 465000.0, 465250.0, 381000.0, 304000.0, 1735000.0, 506000.0, 345000.0, 375000.0, 540000.0, 469000.0, 352450.0, 400000.0, 337000.0, 420000.0, 299995.0, 275000.0, 350000.0, 291500.0, 494000.0, 290000.0, 275000.0, 300000.0, 304000.0, 336500.0, 325000.0, 360000.0, 400000.0, 233000.0, 349000.0, 299900.0, 275500.0, 285000.0, 300000.0, 300000.0, 370000.0, 349810.0, 492650.0, 260000.0, 265000.0, 475000.0, 300000.0, 355000.0, 400000.0, 340000.0, 295950.0, 373000.0, 410000.0, 458400.0, 749950.0, 295000.0, 415000.0, 352500.0, 850000.0, 176225.0, 282508.8889, 229629.5, 282508.8889, 229629.5], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "City=%{x}<br>Price=%{y}", "legendgroup": "City=Kent", "marker": {"color": "#EF553B"}, "name": "City=Kent", "offsetgroup": "City=Kent", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", "Kent", " ...

# %%
# Price
plt.figure(figsize=(18,6))
sns.histplot(data=Df, x="Price", element="step", fill=False)
plt.show()

# %%
plt.figure(figsize=(18,6))

Df.Price.plot()

plt.show()

# %%
# Bedrooms
plt.figure(figsize=(18,6))
sns.countplot(data=Df, x="Bedrooms")
plt.xlabel("Bedrooms")
plt.ylabel(" ")
plt.show()

# %%
plt.figure(figsize=[18,4])
sns.distplot(Df.Bedrooms,color="Green")
plt.xlabel("Bedrooms")
plt.ylabel(" ")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
 px.bar(Df, x='Bedrooms', color="Bedrooms")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="79708d8e-1971-435b-8060-8c9ae7bed652" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("79708d8e-1971-435b-8060-8c9ae7bed652")) {
#                     Plotly.newPlot(
#                         '79708d8e-1971-435b-8060-8c9ae7bed652',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "
 2, 3, 2, 3, 3, 5, 3, 3, 4, 3, 4, 4, 4, 3, 3, 2, 4, 3, 4, 4, 2, 4, 3, 4, 3, 4, 3, 4, 3, 3, 3, 4, 4, 4, 3, 3, 3, 2, 3, 2, 4, 6, 4, 3, 3, 3, 5, 4, 3, 4, 3, 3, 4, 3, 4, 1, 3, 4, 3, 2, 4, 2, 3, 2, 4, 3, 3, 4, 3, 4, 3, 2, 3, 6, 3, 2, 3, 4, 2, 2, 4, 3, 4, 2, 4, 4, 4, 4, 2, 3, 4, 3, 3, 2, 3, 4, 4, 6, 3, 4, 3, 3, 4, 5, 2, 4, 2, 4, 4, 4, 4, 4, 2, 4, 3, 4, 2, 4, 3, 4, 4, 3, 3, 4, 3, 5, 5, 3, 3, 3, 1, 2, 3, 1, 4, 3, 3, 4, 4, 5, 3, 2, 4, 2, 2, 4, 3, 3, 2, 3, 3, 3, 1, 3, 3, 5, 5, 4, 3, 3, 3, 4, 4, 3, 3, 2, 4, 3, 4, 4, 3, 4, 4, 3, 3, 4, 3, 4, 4, 4, 3, 3, 4, 3, 3, 4, 3, 4, 3, 4, 2, 4, 3, 4, 4, 3, 4, 2, 3, 2, ...

# %%
# Bathrooms
plt.figure(figsize=(18,6))
sns.countplot(data=Df, x="Bathrooms")
plt.xlabel("Bathrooms")
plt.ylabel(" ")
plt.show()

# %%
# Bathrooms
plt.figure(figsize=[18,4])
sns.distplot(Df.Bathrooms,color="Green")
plt.xlabel("# Bathrooms")
plt.ylabel(" ")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
# Sqft_lot
plt.figure(figsize=(18,6))
sns.histplot(data=Df, x="Sqft_lot",log_scale=True ,hue="City", element="poly")

# %%
# Sqft_living
plt.figure(figsize=[18,4])
sns.distplot(Df.Sqft_living,color="Green")
plt.xlabel("Sqft_living")
plt.ylabel(" ")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
# Sqft_living
plt.figure(figsize=(18,6))
sns.histplot(data=Df, x="Sqft_living", hue="City", element="poly")

# %%
# Floors
plt.figure(figsize=(18,6))
sns.countplot(data=Df, x="Floors")

# %%
# Floors
plt.figure(figsize=[18,4])
sns.distplot(Df.Floors,color="Green")
plt.xlabel("Floors")
plt.ylabel(" ")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
# Waterfront
plt.figure(figsize=(18,6))
sns.countplot(data=Df, x="Waterfront")

# %%
# View
plt.figure(figsize=(18,6))
sns.countplot(data=Df, x="View")

# %%
# View
plt.figure(figsize=[18,4])
sns.distplot(Df.View,color="Green")
plt.xlabel("View")
plt.ylabel(" ")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
# Condition
plt.figure(figsize=(18,6))
sns.countplot(data=Df, x="Condition")

# %%
# Sqft_above

plt.figure(figsize=(18,6))
sns.histplot(data=Df, x="Sqft_above", element="step", fill=False, hue="City")

# %%
# Sqft_above

plt.figure(figsize=(18,6))
sns.histplot(Df, x="Sqft_above", hue="City", element="step")

# %%
# Condition
plt.figure(figsize=(28,6))
sns.countplot(data=Df, x="Sqft_above")

# %%
# Sqft_basement

plt.figure(figsize=(18,6))
sns.histplot(data=Df, x="Sqft_basement", element="step", fill=False)

# %%
# Yr_built

plt.figure(figsize=(18,6))
sns.histplot(data=Df, x="Yr_built", element="step", fill=False,hue="City")
plt.ylabel(" ")
# Out:
# Text(0, 0.5, ' ')

# %%
from sklearn.preprocessing import  LabelEncoder

Lab_Ecode = LabelEncoder()

# %%
Df.City = Lab_Ecode.fit_transform(Df.City)

# %%
X = Df.drop(columns="Price",axis=1)
Y = Df.Price

# %%
# Feature_importances_
from sklearn.ensemble import ExtraTreesRegressor

Df_Etr = ExtraTreesRegressor()

# %%
Df_Etr.fit(X,Y)
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=100, n_jobs=None, oob_score=False,
#                     random_state=None, verbose=0, warm_start=False)

# %%
Df_Etr.feature_importances_
# Out:
# array([0.03702652, 0.09018843, 0.33312786, 0.04558443, 0.02962022,
#        0.00399833, 0.06769928, 0.02993165, 0.12009209, 0.03634317,
#        0.07696519, 0.02459786, 0.10482496])

# %%
Feature_Imp = pd.Series(Df_Etr.feature_importances_, index=X.columns) 

Feature_Imp.nlargest(20).plot(kind="barh")

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.20,random_state=5)

# %%
print("Shape X_Train -",X_train.shape)
print("Shape Y_Train -",Y_train.shape)
print("Shape X_Test -",X_test.shape)
print("Shape Y_Test -",Y_test.shape)
# Out:
# Shape X_Train - (3604, 13)
# Shape Y_Train - (3604,)
# Shape X_Test - (901, 13)
# Shape Y_Test - (901,)

# %% [markdown]
# ### Linear Regression

# %%
# Linear Regression

from sklearn.linear_model import LinearRegression

Df_Lr = LinearRegression()

# %%
Df_Lr.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Test
Y_Test_Pred = Df_Lr.predict(X_test)

# %%
from sklearn import metrics
from sklearn.metrics import mean_squared_error,r2_score

# %%
# test
print("MAE",metrics.mean_absolute_error(Y_test,Y_Test_Pred))
print("MSE",metrics.mean_squared_error(Y_test,Y_Test_Pred))
print("RMSE",np.sqrt(metrics.mean_squared_error(Y_test,Y_Test_Pred)))
print("R2",metrics.r2_score(Y_test,Y_Test_Pred))
# Out:
# MAE 138422.558801009
# MSE 39394300954.04781
# RMSE 198479.97620427058
# R2 0.5904743813092681

# %% [markdown]
# ### Decision Tree

# %%
# Decision Tree
from sklearn.tree import DecisionTreeRegressor

# %%
Df_Dt = DecisionTreeRegressor()

# %%
Df_Dt.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
Y_Test_Pred = Df_Dt.predict(X_test)

# %%
# Decision Tree
print("MAE",metrics.mean_absolute_error(Y_test,Y_Test_Pred))
print("MSE",metrics.mean_squared_error(Y_test,Y_Test_Pred))
print("RMSE",np.sqrt(metrics.mean_squared_error(Y_test,Y_Test_Pred)))
print("R2",metrics.r2_score(Y_test,Y_Test_Pred))
# Out:
# MAE 151871.927163707
# MSE 56606968752.714
# RMSE 237922.19054286214
# R2 0.4115391480685697

# %% [markdown]
# ### Random Forest Regression

# %%
# Random Forest Regression
from sklearn.ensemble import RandomForestRegressor

# %%
# Creating Object
Df_Rf=RandomForestRegressor(n_estimators=100,random_state=42)

# %%
# fit the model
Df_Rf.fit(X_train,Y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=42, verbose=0, warm_start=False)

# %%
Y_Test_Pred = Df_Rf.predict(X_test)

# %%
# Random Forest
print("MAE",metrics.mean_absolute_error(Y_test,Y_Test_Pred))
print("MSE",metrics.mean_squared_error(Y_test,Y_Test_Pred))
print("RMSE",np.sqrt(metrics.mean_squared_error(Y_test,Y_Test_Pred)))
print("R2",metrics.r2_score(Y_test,Y_Test_Pred))
# Out:
# MAE 107751.35927893786
# MSE 29310496595.657814
# RMSE 171203.08582399387
# R2 0.6953011232139659
