# %%
# Importing Liberies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
# Loading Data(diabetes.csv) with the help odf pandas 
Df = pd.read_csv("diabetes.csv")
Df
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# ..           ...      ...  ...  ...      ...
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [768 rows x 9 columns]

# %%
# Checking First 5 rows 
Df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
# Checking Bottom 5 rows 
Df.tail()
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [5 rows x 9 columns]

# %%
# Checking all coulumns name
Df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
# Checking Data type
Df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
# Data info
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# Checking number of rows and columns 
Df.shape
# Out:
# (768, 9)

# %%
# Checking size of data
Df.size
# Out:
# 6912

# %%
# Number of dimentions 
Df.ndim
# Out:
# 2

# %%
# Chceking Duplicates 
Df.duplicated().sum()
# Out:
# 0

# %%
Df.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  120.894531  ...   33.240885    0.348958
# std       3.369578   31.972618  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %%
# Chcecking na Values
Df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.heatmap(Df.corr(),annot=True,cmap="Greys", cbar=False)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.pairplot(Df,hue="Outcome",kind="hist")
plt.show()

# %%
sns.countplot(Df.Outcome,palette="BuGn")
plt.ylabel(" ")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=Df,x="Pregnancies",fill=False,kde=True,element="step")

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=Df,x="Age",y="Pregnancies")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.scatter(Df["Age"],Df["Pregnancies"],c="red")
plt.xlabel("Age")
plt.ylabel("Pregnancies")
# Out:
# Text(0, 0.5, 'Pregnancies')

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=Df, x="Glucose", kde=True,element="step",fill=False)

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=Df,x="Age",y="Glucose")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=Df,x="BloodPressure",kde=True,element="step",fill=False)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=Df,x="Age",y="BloodPressure")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.scatter(Df["Age"],Df["BloodPressure"],c="green")
plt.xlabel("Age")
plt.ylabel("BloodPressure")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=Df,x="SkinThickness",kde=True,element="step",fill=False)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=Df,x="Age",y="SkinThickness")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.scatter(Df["Age"],Df["SkinThickness"],c="black")
plt.xlabel("Age")
plt.ylabel("SkinThickness")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=Df,x="Insulin",kde=True,element="step",fill=False)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=Df,x="Age",y="Insulin")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.scatter(Df["Age"],Df["Insulin"],c="purple")
plt.xlabel("Age")
plt.ylabel("Insulin")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=Df,x="BMI",kde=True,element="step",fill=False)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=Df,x="Age",y="BMI")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=Df,x="DiabetesPedigreeFunction",kde=True,element="step",fill=False)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=Df,x="Age",y="DiabetesPedigreeFunction")
plt.show()

# %%
X = Df.drop(columns="Outcome", axis=1)
Y = Df.Outcome

# %%
print("Shape of X -",X.shape)
print("Shape of Y -",Y.shape)
# Out:
# Shape of X - (768, 8)
# Shape of Y - (768,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.25,random_state=0)

# %%
print("Shape of X_Train -",X_train.shape)
print("Shape of X_Test -",X_test.shape)
print("Shape of Y_Train -",Y_train.shape)
print("Shape of Y_Test -",Y_test.shape)
# Out:
# Shape of X_Train - (576, 8)
# Shape of X_Test - (192, 8)
# Shape of Y_Train - (576,)
# Shape of Y_Test - (192,)

# %%
#  LogisticRegression
from sklearn.linear_model import LogisticRegression

Df_Lr = LogisticRegression()

# %%
Df_Lr.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
Y_test_Pred = Df_Lr.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
confusion_matrix(Y_test,Y_test_Pred)
# Out:
# array([[115,  15],
#        [ 25,  37]])

# %%
accuracy_score(Y_test,Y_test_Pred)
# Out:
# 0.7916666666666666

# %%
# Decision Tree
from sklearn.tree import DecisionTreeClassifier

Df_Dt = DecisionTreeClassifier()

# %%
Df_Dt.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
Df_test_Pred = Df_Dt.predict(X_test)

# %%
confusion_matrix(Y_test,Y_test_Pred)
# Out:
# array([[115,  15],
#        [ 25,  37]])

# %%
accuracy_score(Y_test,Y_test_Pred)
# Out:
# 0.7916666666666666

# %%
# Rando forest 
from sklearn.ensemble import RandomForestClassifier

Df_Rf = RandomForestClassifier()

# %%
Df_Rf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
Y_test_Pred = Df_Rf.predict(X_test)

# %%
confusion_matrix(Y_test,Y_test_Pred)
# Out:
# array([[116,  14],
#        [ 25,  37]])

# %%
accuracy_score(Y_test,Y_test_Pred)
# Out:
# 0.796875

# %%
# K-Means
from sklearn.cluster import KMeans

Df_Km = KMeans(n_clusters=2)

# %%
Df_Km.fit(X_train,Y_train)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
Df_Km.cluster_centers_
# Out:
# array([[  3.91609977, 115.13378685,  68.89795918,  18.10657596,
#          32.84580499,  31.41088435,   0.43418141,  33.65306122],
#        [  3.59259259, 140.82962963,  72.25185185,  30.99259259,
#         251.88888889,  34.81555556,   0.58079259,  33.35555556]])

# %%
Df_test_Pred = Df_Km.predict(X_test)

# %%
confusion_matrix(Y_test,Y_test_Pred)
# Out:
# array([[115,  15],
#        [ 25,  37]])

# %%
accuracy_score(Y_test,Y_test_Pred)
# Out:
# 0.7916666666666666
